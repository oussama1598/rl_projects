# %%
import os
import sys

sys.path.insert(0, os.path.abspath('../'))

# %%
from src.games.maze_game import MazeGame

game = MazeGame(
    save_to='maze.pkl'
)
game.run(
    verbose=True
)
# game.test()
# Out:
# Episode 1 finished after 38 time steps with total 0.962
# Episode 2 finished after 144 time steps with total 0.8559999999999999
# Episode 3 finished after 534 time steps with total 0.46599999999999964
# Episode 4 finished after 591 time steps with total 0.4089999999999996
# Episode 5 finished after 70 time steps with total 0.9299999999999999
# Episode 6 finished after 543 time steps with total 0.45699999999999963
# Episode 7 finished after 98 time steps with total 0.9019999999999999
# Episode 8 finished after 35 time steps with total 0.965
# Episode 9 finished after 341 time steps with total 0.6589999999999998
# Episode 10 finished after 76 time steps with total 0.9239999999999999
# Episode 11 finished after 29 time steps with total 0.971
# Episode 12 finished after 26 time steps with total 0.974
# Episode 13 finished after 78 time steps with total 0.9219999999999999
# Episode 14 finished after 77 time steps with total 0.9229999999999999
# Episode 15 finished after 61 time steps with total 0.939
# Episode 16 finished after 48 time steps with total 0.952
# Episode 17 finished after 138 time steps with total 0.8619999999999999
# Episode 18 finished after 88 time steps with total 0.9119999999999999
# Episode 19 finished after 92 time steps with total 0.9079999999999999
# Episode 20 finished after 61 time steps with total 0.939
# Episode 21 finished after 21 time steps with total 0.979
# Episode 22 finished after 38 time steps with total 0.962
# Episode 23 finished after 25 time steps with total 0.975
# Episode 24 finished after 177 time steps with total 0.8229999999999998
# Episode 25 finished after 26 time steps with total 0.974
# Episode 26 finished after 47 time steps with total 0.953
# Episode 27 finished after 12 time steps with total 0.988
# Episode 28 finished after 44 time steps with total 0.956
# Episode 29 finished after 12 time steps with total 0.988
# Episode 30 finished after 25 time steps with total 0.975
# Episode 31 finished after 17 time steps with total 0.983
# Episode 32 finished after 16 time steps with total 0.984
# Episode 33 finished after 18 time steps with total 0.982
# Episode 34 finished after 16 time steps with total 0.984
# Episode 35 finished after 26 time steps with total 0.974
# Episode 36 finished after 20 time steps with total 0.98
# Episode 37 finished after 12 time steps with total 0.988
# Episode 38 finished after 18 time steps with total 0.982
# Episode 39 finished after 23 time steps with total 0.977
# Episode 40 finished after 17 time steps with total 0.983
# Episode 41 finished after 11 time steps with total 0.989
# Episode 42 finished after 264 time steps with total 0.7359999999999998
# Episode 43 finished after 12 time steps with total 0.988
# Episode 44 finished after 34 time steps with total 0.966
# Episode 45 finished after 16 time steps with total 0.984
# Episode 46 finished after 16 time steps with total 0.984
# Episode 47 finished after 12 time steps with total 0.988
# Episode 48 finished after 17 time steps with total 0.983
# Episode 49 finished after 18 time steps with total 0.982
# Episode 50 finished after 17 time steps with total 0.983
# Episode 51 finished after 20 time steps with total 0.98
# Episode 52 finished after 19 time steps with total 0.981
# Episode 53 finished after 13 time steps with total 0.987
# Episode 54 finished after 9 time steps with total 0.991
# Episode 55 finished after 13 time steps with total 0.987
# Episode 56 finished after 11 time steps with total 0.989
# Episode 57 finished after 11 time steps with total 0.989
# Episode 58 finished after 15 time steps with total 0.985
# Episode 59 finished after 10 time steps with total 0.99
# Episode 60 finished after 14 time steps with total 0.986
# Episode 61 finished after 11 time steps with total 0.989
# Episode 62 finished after 13 time steps with total 0.987
# Episode 63 finished after 9 time steps with total 0.991
# Episode 64 finished after 14 time steps with total 0.986
# Episode 65 finished after 12 time steps with total 0.988
# Episode 66 finished after 20 time steps with total 0.98
# Episode 67 finished after 19 time steps with total 0.981
# Episode 68 finished after 12 time steps with total 0.988
# Episode 69 finished after 16 time steps with total 0.984
# Episode 70 finished after 9 time steps with total 0.991
# Episode 71 finished after 13 time steps with total 0.987
# Episode 72 finished after 10 time steps with total 0.99
# Episode 73 finished after 11 time steps with total 0.989
# Episode 74 finished after 10 time steps with total 0.99
# Episode 75 finished after 9 time steps with total 0.991
# Episode 76 finished after 12 time steps with total 0.988
# Episode 77 finished after 11 time steps with total 0.989
# Episode 78 finished after 9 time steps with total 0.991
# Episode 79 finished after 9 time steps with total 0.991
# Episode 80 finished after 12 time steps with total 0.988
# Episode 81 finished after 9 time steps with total 0.991
# Episode 82 finished after 13 time steps with total 0.987
# Episode 83 finished after 10 time steps with total 0.99
# Episode 84 finished after 9 time steps with total 0.991
# Episode 85 finished after 9 time steps with total 0.991
# Episode 86 finished after 9 time steps with total 0.991
# Episode 87 finished after 9 time steps with total 0.991
# Episode 88 finished after 12 time steps with total 0.988
# Episode 89 finished after 9 time steps with total 0.991
# Episode 90 finished after 9 time steps with total 0.991
# Episode 91 finished after 9 time steps with total 0.991
# Episode 92 finished after 9 time steps with total 0.991
# Episode 93 finished after 9 time steps with total 0.991
# Episode 94 finished after 9 time steps with total 0.991
# Episode 95 finished after 10 time steps with total 0.99
# Episode 96 finished after 10 time steps with total 0.99
# Episode 97 finished after 9 time steps with total 0.991
# Episode 98 finished after 9 time steps with total 0.991
# Episode 99 finished after 11 time steps with total 0.989
# Episode 100 finished after 9 time steps with total 0.991
# Episode 101 finished after 9 time steps with total 0.991
# Episode 102 finished after 9 time steps with total 0.991
# Episode 103 finished after 9 time steps with total 0.991
# Episode 104 finished after 9 time steps with total 0.991
# Episode 105 finished after 9 time steps with total 0.991
# Episode 106 finished after 9 time steps with total 0.991
# Episode 107 finished after 9 time steps with total 0.991
# Episode 108 finished after 9 time steps with total 0.991
# Episode 109 finished after 9 time steps with total 0.991
# Episode 110 finished after 9 time steps with total 0.991
# Episode 111 finished after 9 time steps with total 0.991
# Episode 112 finished after 9 time steps with total 0.991
# Episode 113 finished after 9 time steps with total 0.991
# Episode 114 finished after 9 time steps with total 0.991
# Episode 115 finished after 9 time steps with total 0.991
# Episode 116 finished after 9 time steps with total 0.991
# Episode 117 finished after 9 time steps with total 0.991
# Episode 118 finished after 9 time steps with total 0.991
# Episode 119 finished after 9 time steps with total 0.991
# Episode 120 finished after 9 time steps with total 0.991
# Episode 121 finished after 9 time steps with total 0.991
# Episode 122 finished after 9 time steps with total 0.991
# Episode 123 finished after 9 time steps with total 0.991
# Episode 124 finished after 9 time steps with total 0.991
# Episode 125 finished after 9 time steps with total 0.991
# Episode 126 finished after 9 time steps with total 0.991
# Episode 127 finished after 9 time steps with total 0.991
# Episode 128 finished after 9 time steps with total 0.991
# Episode 129 finished after 9 time steps with total 0.991
# Episode 130 finished after 9 time steps with total 0.991
# Episode 131 finished after 9 time steps with total 0.991
# Episode 132 finished after 9 time steps with total 0.991
# Episode 133 finished after 9 time steps with total 0.991
# Episode 134 finished after 9 time steps with total 0.991
# Episode 135 finished after 9 time steps with total 0.991
# Episode 136 finished after 9 time steps with total 0.991
# Episode 137 finished after 9 time steps with total 0.991
# Episode 138 finished after 9 time steps with total 0.991
# Episode 139 finished after 9 time steps with total 0.991
# Episode 140 finished after 9 time steps with total 0.991
# Episode 141 finished after 9 time steps with total 0.991
# Episode 142 finished after 9 time steps with total 0.991
# Episode 143 finished after 9 time steps with total 0.991
# Episode 144 finished after 9 time steps with total 0.991
# Episode 145 finished after 9 time steps with total 0.991
# Episode 146 finished after 9 time steps with total 0.991
# Episode 147 finished after 9 time steps with total 0.991
# Episode 148 finished after 9 time steps with total 0.991
# Episode 149 finished after 9 time steps with total 0.991
# Episode 150 finished after 9 time steps with total 0.991

# %%
import matplotlib.pyplot as plt

plt.plot(game.agent.rewards)
plt.title('Rewards per episode')
plt.xlabel('Episodes')
plt.ylabel('Reward')
plt.savefig('../images/q_learning_reward_per_episode.png')
