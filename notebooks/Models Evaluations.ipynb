# %%
import os
import sys

sys.path.insert(0, os.path.abspath('../'))

# %%
from src.games.maze_game import MazeGame

game = MazeGame(save_model=False)
game.run()
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import matplotlib.pyplot as plt

plt.plot(game.agent.rewards)
plt.title('Rewards per episode')
plt.xlabel('Episodes')
plt.ylabel('Reward')
plt.savefig('../images/q_learning_reward_per_episode.png')

# %%
from src.games.sarsa_maze_game import SarsaMazeGame

game = SarsaMazeGame(save_model=False)
game.run()
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import matplotlib.pyplot as plt

plt.plot(game.agent.rewards)
plt.title('Rewards per episode')
plt.xlabel('Episodes')
plt.ylabel('Reward')
plt.savefig('../images/sarsa_reward_per_episode.png')

# %%
from src.games.dq_cartpole_game import DQCartpoleGame

game = DQCartpoleGame(save_model=False)
game.run(verbose=True, num_episodes=1000)
# Out:
# Episode 1 finished with total 16.0
# Episode 2 finished with total 14.0
# Episode 3 finished with total 22.0
# Episode 4 finished with total 11.0
# Episode 5 finished with total 46.0
# Episode 6 finished with total 24.0
# Episode 7 finished with total 17.0
# Episode 8 finished with total 46.0
# Episode 9 finished with total 14.0
# Episode 10 finished with total 16.0
# Episode 11 finished with total 27.0
# Episode 12 finished with total 18.0
# Episode 13 finished with total 12.0
# Episode 14 finished with total 11.0
# Episode 15 finished with total 16.0
# Episode 16 finished with total 28.0
# Episode 17 finished with total 13.0
# Episode 18 finished with total 11.0
# Episode 19 finished with total 34.0
# Episode 20 finished with total 9.0
# Episode 21 finished with total 24.0
# Episode 22 finished with total 11.0
# Episode 23 finished with total 27.0
# Episode 24 finished with total 55.0
# Episode 25 finished with total 20.0
# Episode 26 finished with total 15.0
# ...
